# %% [markdown]
# # Agent-Based Modeling Digitial Day of Learning Workshop
# ## Forrest Fire Model in Mesa
# ### Joseph Engler, PhD & Chris Reuter

# %% [markdown]
# For this exercise we will use a python library called Mesa. Mesa was created specifically for Agent-based modeling and is the standard at many research institutions globally.

# %%
# !pip install --proxy http://proxy.rockwellcollins.com:9090 mesa
# Out:
# Requirement already satisfied: mesa in d:\anaconda\lib\site-packages (2.4.0)
# Requirement already satisfied: networkx in d:\anaconda\lib\site-packages (from mesa) (2.8.4)
# Requirement already satisfied: solara in d:\anaconda\lib\site-packages (from mesa) (1.51.1)
# Requirement already satisfied: matplotlib in d:\anaconda\lib\site-packages (from mesa) (3.5.2)
# Requirement already satisfied: pandas in d:\anaconda\lib\site-packages (from mesa) (1.4.4)
# Requirement already satisfied: cookiecutter in d:\anaconda\lib\site-packages (from mesa) (1.7.3)
# Requirement already satisfied: mesa-viz-tornado>=0.1.3,~=0.1.0 in d:\anaconda\lib\site-packages (from mesa) (0.1.3)
# Requirement already satisfied: tqdm in d:\anaconda\lib\site-packages (from mesa) (4.64.1)
# Requirement already satisfied: numpy in d:\anaconda\lib\site-packages (from mesa) (1.21.5)
# Requirement already satisfied: click in d:\anaconda\lib\site-packages (from mesa) (8.0.4)
# Requirement already satisfied: tornado in d:\anaconda\lib\site-packages (from mesa-viz-tornado>=0.1.3,~=0.1.0->mesa) (6.1)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from click->mesa) (0.4.5)
# Requirement already satisfied: poyo>=0.5.0 in d:\anaconda\lib\site-packages (from cookiecutter->mesa) (0.5.0)
# Requirement already satisfied: jinja2-time>=0.2.0 in d:\anaconda\lib\site-packages (from cookiecutter->mesa) (0.2.0)
# Requirement already satisfied: binaryornot>=0.4.4 in d:\anaconda\lib\site-packages (from cookiecutter->mesa) (0.4.4)
# Requirement already satisfied: six>=1.10 in d:\anaconda\lib\site-packages (from cookiecutter->mesa) (1.16.0)
# Requirement already satisfied: requests>=2.23.0 in d:\anaconda\lib\site-packages (from cookiecutter->mesa) (2.28.1)
# Requirement already satisfied: Jinja2<4.0.0,>=2.7 in d:\anaconda\lib\site-packages (from cookiecutter->mesa) (2.11.3)
# Requirement already satisfied: python-slugify>=4.0.0 in d:\anaconda\lib\site-packages (from cookiecutter->mesa) (5.0.2)
# Requirement already satisfied: python-dateutil>=2.7 in d:\anaconda\lib\site-packages (from matplotlib->mesa) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in d:\anaconda\lib\site-packages (from matplotlib->mesa) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in d:\anaconda\lib\site-packages (from matplotlib->mesa) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in d:\anaconda\lib\site-packages (from matplotlib->mesa) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in d:\anaconda\lib\site-packages (from matplotlib->mesa) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in d:\anaconda\lib\site-packages (from matplotlib->mesa) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in d:\anaconda\lib\site-packages (from matplotlib->mesa) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in d:\anaconda\lib\site-packages (from pandas->mesa) (2022.1)
# Requirement already satisfied: solara-ui[all]==1.51.1 in d:\anaconda\lib\site-packages (from solara->mesa) (1.51.1)
# Requirement already satisfied: solara-server[dev,starlette]==1.51.1 in d:\anaconda\lib\site-packages (from solara->mesa) (1.51.1)
# Requirement already satisfied: ipykernel in d:\anaconda\lib\site-packages (from solara-server[dev,starlette]==1.51.1->solara->mesa) (6.15.2)
# Requirement already satisfied: filelock in d:\anaconda\lib\site-packages (from solara-server[dev,starlette]==1.51.1->solara->mesa) (3.6.0)
# Requirement already satisfied: nbformat in d:\anaconda\lib\site-packages (from solara-server[dev,starlette]==1.51.1->solara->mesa) (5.5.0)
# Requirement already satisfied: jupyter-client in d:\anaconda\lib\site-packages (from solara-server[dev,starlette]==1.51.1->solara->mesa) (7.3.4)
# Requirement already satisfied: rich-click in d:\anaconda\lib\site-packages (from solara-server[dev,starlette]==1.51.1->solara->mesa) (1.9.3)
# Requirement already satisfied: watchdog in d:\anaconda\lib\site-packages (from solara-server[dev,starlette]==1.51.1->solara->mesa) (2.1.6)
# Requirement already satisfied: watchfiles in d:\anaconda\lib\site-packages (from solara-server[dev,starlette]==1.51.1->solara->mesa) (1.1.1)
# Requirement already satisfied: starlette in d:\anaconda\lib\site-packages (from solara-server[dev,starlette]==1.51.1->solara->mesa) (0.48.0)
# Requirement already satisfied: uvicorn in d:\anaconda\lib\site-packages (from solara-server[dev,starlette]==1.51.1->solara->mesa) (0.37.0)
# Requirement already satisfied: websockets in d:\anaconda\lib\site-packages (from solara-server[dev,starlette]==1.51.1->solara->mesa) (15.0.1)
# Requirement already satisfied: reacton>=1.9 in d:\anaconda\lib\site-packages (from solara-ui[all]==1.51.1->solara->mesa) (1.9.1)
# Requirement already satisfied: ipywidgets>=7.7 in d:\anaconda\lib\site-packages (from solara-ui[all]==1.51.1->solara->mesa) (8.1.7)
# Requirement already satisfied: humanize in d:\anaconda\lib\site-packages (from solara-ui[all]==1.51.1->solara->mesa) (4.13.0)
# Requirement already satisfied: ipyvuetify>=1.6.10 in d:\anaconda\lib\site-packages (from solara-ui[all]==1.51.1->solara->mesa) (1.11.3)
# Requirement already satisfied: ipyvue>=1.9.0 in d:\anaconda\lib\site-packages (from solara-ui[all]==1.51.1->solara->mesa) (1.11.3)
# Requirement already satisfied: pymdown-extensions in d:\anaconda\lib\site-packages (from solara-ui[all]==1.51.1->solara->mesa) (10.16.1)
# Requirement already satisfied: pygments in d:\anaconda\lib\site-packages (from solara-ui[all]==1.51.1->solara->mesa) (2.19.2)
# Requirement already satisfied: markdown in d:\anaconda\lib\site-packages (from solara-ui[all]==1.51.1->solara->mesa) (3.9)
# Requirement already satisfied: cachetools in d:\anaconda\lib\site-packages (from solara-ui[all]==1.51.1->solara->mesa) (6.2.1)
# Requirement already satisfied: chardet>=3.0.2 in d:\anaconda\lib\site-packages (from binaryornot>=0.4.4->cookiecutter->mesa) (4.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anaconda\lib\site-packages (from Jinja2<4.0.0,>=2.7->cookiecutter->mesa) (2.0.1)
# Requirement already satisfied: arrow in d:\anaconda\lib\site-packages (from jinja2-time>=0.2.0->cookiecutter->mesa) (1.2.2)
# Requirement already satisfied: text-unidecode>=1.3 in d:\anaconda\lib\site-packages (from python-slugify>=4.0.0->cookiecutter->mesa) (1.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests>=2.23.0->cookiecutter->mesa) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests>=2.23.0->cookiecutter->mesa) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in d:\anaconda\lib\site-packages (from requests>=2.23.0->cookiecutter->mesa) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in d:\anaconda\lib\site-packages (from requests>=2.23.0->cookiecutter->mesa) (1.26.11)
# Requirement already satisfied: ipython>=6.1.0 in d:\anaconda\lib\site-packages (from ipywidgets>=7.7->solara-ui[all]==1.51.1->solara->mesa) (7.31.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in d:\anaconda\lib\site-packages (from ipywidgets>=7.7->solara-ui[all]==1.51.1->solara->mesa) (4.0.14)
# Requirement already satisfied: comm>=0.1.3 in d:\anaconda\lib\site-packages (from ipywidgets>=7.7->solara-ui[all]==1.51.1->solara->mesa) (0.2.3)
# Requirement already satisfied: traitlets>=4.3.1 in d:\anaconda\lib\site-packages (from ipywidgets>=7.7->solara-ui[all]==1.51.1->solara->mesa) (5.1.1)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in d:\anaconda\lib\site-packages (from ipywidgets>=7.7->solara-ui[all]==1.51.1->solara->mesa) (3.0.15)
# Requirement already satisfied: typing-extensions>=4.1.1 in d:\anaconda\lib\site-packages (from reacton>=1.9->solara-ui[all]==1.51.1->solara->mesa) (4.15.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in d:\anaconda\lib\site-packages (from ipykernel->solara-server[dev,starlette]==1.51.1->solara->mesa) (0.1.6)
# Requirement already satisfied: psutil in d:\anaconda\lib\site-packages (from ipykernel->solara-server[dev,starlette]==1.51.1->solara->mesa) (5.9.0)
# Requirement already satisfied: debugpy>=1.0 in d:\anaconda\lib\site-packages (from ipykernel->solara-server[dev,starlette]==1.51.1->solara->mesa) (1.5.1)
# Requirement already satisfied: pyzmq>=17 in d:\anaconda\lib\site-packages (from ipykernel->solara-server[dev,starlette]==1.51.1->solara->mesa) (23.2.0)
# Requirement already satisfied: nest-asyncio in d:\anaconda\lib\site-packages (from ipykernel->solara-server[dev,starlette]==1.51.1->solara->mesa) (1.5.5)
# Requirement already satisfied: jupyter-core>=4.9.2 in d:\anaconda\lib\site-packages (from jupyter-client->solara-server[dev,starlette]==1.51.1->solara->mesa) (4.11.1)
# Requirement already satisfied: entrypoints in d:\anaconda\lib\site-packages (from jupyter-client->solara-server[dev,starlette]==1.51.1->solara->mesa) (0.4)
# Requirement already satisfied: importlib-metadata>=4.4 in d:\anaconda\lib\site-packages (from markdown->solara-ui[all]==1.51.1->solara->mesa) (4.11.3)
# Requirement already satisfied: fastjsonschema in d:\anaconda\lib\site-packages (from nbformat->solara-server[dev,starlette]==1.51.1->solara->mesa) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in d:\anaconda\lib\site-packages (from nbformat->solara-server[dev,starlette]==1.51.1->solara->mesa) (4.16.0)
# Requirement already satisfied: pyyaml in d:\anaconda\lib\site-packages (from pymdown-extensions->solara-ui[all]==1.51.1->solara->mesa) (6.0)
# Requirement already satisfied: rich>=12 in d:\anaconda\lib\site-packages (from rich-click->solara-server[dev,starlette]==1.51.1->solara->mesa) (14.2.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in d:\anaconda\lib\site-packages (from starlette->solara-server[dev,starlette]==1.51.1->solara->mesa) (4.11.0)
# Requirement already satisfied: h11>=0.8 in d:\anaconda\lib\site-packages (from uvicorn->solara-server[dev,starlette]==1.51.1->solara->mesa) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in d:\anaconda\lib\site-packages (from anyio<5,>=3.6.2->starlette->solara-server[dev,starlette]==1.51.1->solara->mesa) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in d:\anaconda\lib\site-packages (from anyio<5,>=3.6.2->starlette->solara-server[dev,starlette]==1.51.1->solara->mesa) (1.3.0)
# Requirement already satisfied: zipp>=0.5 in d:\anaconda\lib\site-packages (from importlib-metadata>=4.4->markdown->solara-ui[all]==1.51.1->solara->mesa) (3.8.0)
# Requirement already satisfied: setuptools>=18.5 in d:\anaconda\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.7->solara-ui[all]==1.51.1->solara->mesa) (63.4.1)
# Requirement already satisfied: backcall in d:\anaconda\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.7->solara-ui[all]==1.51.1->solara->mesa) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in d:\anaconda\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.7->solara-ui[all]==1.51.1->solara->mesa) (3.0.20)
# Requirement already satisfied: decorator in d:\anaconda\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.7->solara-ui[all]==1.51.1->solara->mesa) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in d:\anaconda\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.7->solara-ui[all]==1.51.1->solara->mesa) (0.18.1)
# Requirement already satisfied: pickleshare in d:\anaconda\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.7->solara-ui[all]==1.51.1->solara->mesa) (0.7.5)
# Requirement already satisfied: attrs>=17.4.0 in d:\anaconda\lib\site-packages (from jsonschema>=2.6->nbformat->solara-server[dev,starlette]==1.51.1->solara->mesa) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in d:\anaconda\lib\site-packages (from jsonschema>=2.6->nbformat->solara-server[dev,starlette]==1.51.1->solara->mesa) (0.18.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\e10656503.adxu\appdata\roaming\python\python39\site-packages (from jupyter-core>=4.9.2->jupyter-client->solara-server[dev,starlette]==1.51.1->solara->mesa) (306)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\anaconda\lib\site-packages (from rich>=12->rich-click->solara-server[dev,starlette]==1.51.1->solara->mesa) (3.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in d:\anaconda\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.7->solara-ui[all]==1.51.1->solara->mesa) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12->rich-click->solara-server[dev,starlette]==1.51.1->solara->mesa) (0.1.2)
# Requirement already satisfied: wcwidth in d:\anaconda\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets>=7.7->solara-ui[all]==1.51.1->solara->mesa) (0.2.5)

# %%
import mesa
import matplotlib.pyplot as plt
import nest_asyncio
import warnings

warnings.filterwarnings('ignore')
nest_asyncio.apply()

# %% [markdown]
# # Creating a the Agent-Based Model
# The Agent-based model is performed on a grid. Each cell of the grid can have various properties and components of the model. Once the model is completely setup then we can run the model. Running the model consists of individual time steps in which the model, agents, and other components perform some tasks. We will begin with creating the agents of the model.

# %% [markdown]
# ## Creating Agents
# Mesa uses agents as the main object of modelling. We will create an agent that will represent a section of the forest. Agents are a class in Mesa that we will extend and pass it the required variables of the model and the agent's unique id. Agents also have a method called step that we need to overload. During the step the agent will determine if it is on fire and if it is, then it will light its neighbors on fire.

# %%
class Forest(mesa.Agent):
    def __init__(self, unique_id, model, position):
        super().__init__(unique_id, model)
        self.pos = position
        self.status = "Fine"
        
    def step(self):
        if self.status == "Burning":
            for neighbor in self.model.grid.iter_neighbors(self.pos, True):
                if neighbor.status == "Fine":
                    if self.model.random.random() > 0.75:
                        neighbor.status = "Burning"
                self.status = "Burned"
        
        #TODO
        #Develop logic for regenerating the forest after being burnt

# %% [markdown]
# ## Creating the Model
# The model is a Mesa class that we will extend just like we did with the agents. The model is the controller of the overall Agent-based Model

# %%
class ForestFire(mesa.Model):
    def __init__(
        self,
        width = 100,
        height = 100,
        density=0.65):
        
        super().__init__()
        self.width = width
        self.height = height
        self.density = density
        self.schedule = mesa.time.RandomActivation(self)
        self.grid = mesa.space.SingleGrid(self.width, self.height, torus=False)
        self.datacollector = mesa.DataCollector(
            model_reporters={
                "Fine": lambda model: self.count_type(model, "Fine"),
                "Burning": lambda model: self.count_type(model, "Burning"),
                "Burned": lambda model: self.count_type(model, "Burned"),
                #TODO: Add output for regeneration
            }
        )
        self._initialize_forest()
        self.datacollector.collect(self)
        
        
    def _initialize_forest(self):
        for _contents, pos in self.grid.coord_iter():
            forest = Forest(self.next_id(), self, pos)
            if self.random.random() < self.density:
                if pos[0] == 0: #set this section to burning
                    forest.status = "Burning"
                else:
                    forest.status = "Fine"
            else:
                forest.status = "Burned"
            self.schedule.add(forest)
            self.grid.place_agent(forest, pos)
            
    def step(self):
        self.schedule.step()
        self.datacollector.collect(self)
        
    @staticmethod
    def count_type(model, status):
        count = 0
        for forest in model.schedule.agents:
            if forest.status == status:
                count += 1
        return count

# %% [markdown]
# ## Create the Server to Run the Model

# %%
GRID_WIDTH = 100
GRID_HEIGHT = 100
CANVAS_WIDTH = 500
CANVAS_HEIGHT = 500

COLORS = {
    "Fine": "#00AA00",
    "Burning": "#FF0000",
    "Burned": "#3D2B1F",
}

def forest_portrayal(forest):
    if not forest:
        return

    (x, y) = forest.pos
    return {
        "Shape": "rect",
        "w": 1,
        "h": 1,
        "Filled": True,
        "Layer": 0,
        "x": x,
        "y": y,
        "Color": COLORS[forest.status],
    }

canvas_element = mesa.visualization.CanvasGrid(
    forest_portrayal, GRID_WIDTH, GRID_HEIGHT, CANVAS_WIDTH, CANVAS_HEIGHT
)

forest_chart = mesa.visualization.ChartModule(
    [{"Label": label, "Color": color} for (label, color) in COLORS.items()]
)

pie_chart = mesa.visualization.PieChartModule(
    [{"Label": label, "Color": color} for (label, color) in COLORS.items()]
)

model_params = {
    "width": GRID_WIDTH,
    "height": GRID_HEIGHT,
    "density": mesa.visualization.Slider("Forest Density", 0.65, 0.01, 1.0, 0.01),
    #TODO: Add a slider that will determine the speed at which the forests regenerate
}



server = mesa.visualization.ModularServer(
    ForestFire, [canvas_element, forest_chart, pie_chart], "Forest Fire", model_params, port=8522
)

# %%
server.launch(open_browser=True)

# %% [markdown]
# # Power of Experimentation
#
# The power of Agent-based Modeling is that you can easily explore many hypotheses and determine how they effective they are by adding them to the model and running it.
#
# Using the model and agent definitions above, you can explore many other scenarios by which forest fire damage can be mitigated. Try adding a status of "Fire Break" that can not catch fire and see how that benefits or hurts the forests during fire conditions.
