# %%
# !pip install mesa==2.4.0
# Out:
# Requirement already satisfied: mesa==2.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-89b053ed-ead1-42ab-a05c-ec30267b139d/lib/python3.12/site-packages (2.4.0)
# Requirement already satisfied: click in /databricks/python3/lib/python3.12/site-packages (from mesa==2.4.0) (8.1.7)
# Requirement already satisfied: cookiecutter in /local_disk0/.ephemeral_nfs/envs/pythonEnv-89b053ed-ead1-42ab-a05c-ec30267b139d/lib/python3.12/site-packages (from mesa==2.4.0) (2.6.0)
# Requirement already satisfied: matplotlib in /databricks/python3/lib/python3.12/site-packages (from mesa==2.4.0) (3.10.0)
# Requirement already satisfied: mesa-viz-tornado>=0.1.3,~=0.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-89b053ed-ead1-42ab-a05c-ec30267b139d/lib/python3.12/site-packages (from mesa==2.4.0) (0.1.3)
# Requirement already satisfied: networkx in /local_disk0/.ephemeral_nfs/envs/pythonEnv-89b053ed-ead1-42ab-a05c-ec30267b139d/lib/python3.12/site-packages (from mesa==2.4.0) (3.5)
# Requirement already satisfied: numpy in /databricks/python3/lib/python3.12/site-packages (from mesa==2.4.0) (2.1.3)
# Requirement already satisfied: pandas in /databricks/python3/lib/python3.12/site-packages (from mesa==2.4.0) (2.2.3)
# Requirement already satisfied: solara in /local_disk0/.ephemeral_nfs/envs/pythonEnv-89b053ed-ead1-42ab-a05c-ec30267b139d/lib/python3.12/site-packages (from mesa==2.4.0) (1.52.0)
# Requirement already satisfied: tqdm in /local_disk0/.ephemeral_nfs/envs/pythonEnv-89b053ed-ead1-42ab-a05c-ec30267b139d/lib/python3.12/site-packages (from mesa==2.4.0) (4.67.1)
# Requirement already satisfied: tornado in /databricks/python3/lib/python3.12/site-packages (from mesa-viz-tornado>=0.1.3,~=0.1.0->mesa==2.4.0) (6.4.2)
# Requirement already satisfied: binaryornot>=0.4.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-89b053ed-ead1-42ab-a05c-ec30267b139d/lib/python3.12/site-packages (from cookiecutter->mesa==2.4.0) (0.4.4)
# Requirement already satisfied: Jinja2<4.0.0,>=2.7 in /databricks/python3/lib/python3.12/site-packages (from cookiecutter->mesa==2.4.0) (3.1.5)
# Requirement already satisfied: pyyaml>=5.3.1 in /databricks/python3/lib/python3.12/site-packages (from cookiecutter->mesa==2.4.0) (6.0.2)
# Requirement already satisfied: python-slugify>=4.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-89b053ed-ead1-42ab-a05c-ec30267b139d/lib/python3.12/site-packages (from cookiecutter->mesa==2.4.0) (8.0.4)
# Requirement already satisfied: requests>=2.23.0 in /databricks/python3/lib/python3.12/site-packages (from cookiecutter->mesa==2.4.0) (2.32.3)
# Requirement already satisfied: arrow in /databricks/python3/lib/python3.12/site-packages (from cookiecutter->mesa==2.4.0) (1.3.0)
# Requirement already satisfied: rich in /databricks/python3/lib/python3.12/site-packages (from cookiecutter->mesa==2.4.0) (13.9.4)
# Requirement already satisfied: contourpy>=1.0.1 in /databricks/python3/lib/python3.12/site-packages (from matplotlib->mesa==2.4.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.12/site-packages (from matplotlib->mesa==2.4.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /databricks/python3/lib/python3.12/site-packages (from matplotlib->mesa==2.4.0) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /databricks/python3/lib/python3.12/site-packages (from matplotlib->mesa==2.4.0) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /databricks/python3/lib/python3.12/site-packages (from matplotlib->mesa==2.4.0) (24.1)
# Requirement already satisfied: pillow>=8 in /databricks/python3/lib/python3.12/site-packages (from matplotlib->mesa==2.4.0) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /databricks/python3/lib/python3.12/site-packages (from matplotlib->mesa==2.4.0) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /databricks/python3/lib/python3.12/site-packages (from matplotlib->mesa==2.4.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.12/site-packages (from pandas->mesa==2.4.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /databricks/python3/lib/python3.12/site-packages (from pandas->mesa==2.4.0) (2024.1)
# Requirement already satisfied: solara-server==1.52.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-89b053ed-ead1-42ab-a05c-ec30267b139d/lib/python3.12/site-packages (from solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (1.52.0)
# Requirement already satisfied: solara-ui==1.52.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-89b053ed-ead1-42ab-a05c-ec30267b139d/lib/python3.12/site-packages (from solara-ui[all]==1.52.0->solara->mesa==2.4.0) (1.52.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (3.18.0)
# Requirement already satisfied: ipykernel!=7.0.0,!=7.0.1 in /databricks/python3/lib/python3.12/site-packages (from solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (6.29.5)
# Requirement already satisfied: jupyter-client in /databricks/python3/lib/python3.12/site-packages (from solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (8.6.3)
# Requirement already satisfied: nbformat in /databricks/python3/lib/python3.12/site-packages (from solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (5.10.4)
# Requirement already satisfied: rich-click in /local_disk0/.ephemeral_nfs/envs/pythonEnv-89b053ed-ead1-42ab-a05c-ec30267b139d/lib/python3.12/site-packages (from solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (1.9.3)
# Requirement already satisfied: starlette in /databricks/python3/lib/python3.12/site-packages (from solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (0.46.2)
# Requirement already satisfied: uvicorn in /databricks/python3/lib/python3.12/site-packages (from solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (0.34.2)
# Requirement already satisfied: websockets in /local_disk0/.ephemeral_nfs/envs/pythonEnv-89b053ed-ead1-42ab-a05c-ec30267b139d/lib/python3.12/site-packages (from solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (15.0.1)
# Requirement already satisfied: watchdog in /local_disk0/.ephemeral_nfs/envs/pythonEnv-89b053ed-ead1-42ab-a05c-ec30267b139d/lib/python3.12/site-packages (from solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (6.0.0)
# Requirement already satisfied: watchfiles in /local_disk0/.ephemeral_nfs/envs/pythonEnv-89b053ed-ead1-42ab-a05c-ec30267b139d/lib/python3.12/site-packages (from solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (1.1.1)
# Requirement already satisfied: humanize in /local_disk0/.ephemeral_nfs/envs/pythonEnv-89b053ed-ead1-42ab-a05c-ec30267b139d/lib/python3.12/site-packages (from solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (4.14.0)
# Requirement already satisfied: ipyvue>=1.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-89b053ed-ead1-42ab-a05c-ec30267b139d/lib/python3.12/site-packages (from solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (1.11.3)
# Requirement already satisfied: ipyvuetify>=1.6.10 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-89b053ed-ead1-42ab-a05c-ec30267b139d/lib/python3.12/site-packages (from solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (1.11.3)
# Requirement already satisfied: ipywidgets>=7.7 in /databricks/python3/lib/python3.12/site-packages (from solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (7.8.1)
# Requirement already satisfied: reacton>=1.9 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-89b053ed-ead1-42ab-a05c-ec30267b139d/lib/python3.12/site-packages (from solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (1.9.1)
# Requirement already satisfied: cachetools in /databricks/python3/lib/python3.12/site-packages (from solara-ui[all]==1.52.0->solara->mesa==2.4.0) (5.5.1)
# Requirement already satisfied: markdown in /local_disk0/.ephemeral_nfs/envs/pythonEnv-89b053ed-ead1-42ab-a05c-ec30267b139d/lib/python3.12/site-packages (from solara-ui[all]==1.52.0->solara->mesa==2.4.0) (3.9)
# Requirement already satisfied: pygments in /databricks/python3/lib/python3.12/site-packages (from solara-ui[all]==1.52.0->solara->mesa==2.4.0) (2.15.1)
# Requirement already satisfied: pymdown-extensions in /local_disk0/.ephemeral_nfs/envs/pythonEnv-89b053ed-ead1-42ab-a05c-ec30267b139d/lib/python3.12/site-packages (from solara-ui[all]==1.52.0->solara->mesa==2.4.0) (10.16.1)
# Requirement already satisfied: chardet>=3.0.2 in /databricks/python3/lib/python3.12/site-packages (from binaryornot>=0.4.4->cookiecutter->mesa==2.4.0) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /databricks/python3/lib/python3.12/site-packages (from Jinja2<4.0.0,>=2.7->cookiecutter->mesa==2.4.0) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.7->matplotlib->mesa==2.4.0) (1.16.0)
# Requirement already satisfied: text-unidecode>=1.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-89b053ed-ead1-42ab-a05c-ec30267b139d/lib/python3.12/site-packages (from python-slugify>=4.0.0->cookiecutter->mesa==2.4.0) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.12/site-packages (from requests>=2.23.0->cookiecutter->mesa==2.4.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.12/site-packages (from requests>=2.23.0->cookiecutter->mesa==2.4.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /databricks/python3/lib/python3.12/site-packages (from requests>=2.23.0->cookiecutter->mesa==2.4.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.12/site-packages (from requests>=2.23.0->cookiecutter->mesa==2.4.0) (2025.1.31)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /databricks/python3/lib/python3.12/site-packages (from arrow->cookiecutter->mesa==2.4.0) (2.9.0.20241206)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /databricks/python3/lib/python3.12/site-packages (from rich->cookiecutter->mesa==2.4.0) (2.2.0)
# Requirement already satisfied: comm>=0.1.1 in /databricks/python3/lib/python3.12/site-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /databricks/python3/lib/python3.12/site-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (1.8.11)
# Requirement already satisfied: ipython>=7.23.1 in /databricks/python3/lib/python3.12/site-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (8.30.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /databricks/python3/lib/python3.12/site-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /databricks/python3/lib/python3.12/site-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (0.1.7)
# Requirement already satisfied: nest-asyncio in /databricks/python3/lib/python3.12/site-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (1.6.0)
# Requirement already satisfied: psutil in /databricks/python3/lib/python3.12/site-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in /databricks/python3/lib/python3.12/site-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (26.2.0)
# Requirement already satisfied: traitlets>=5.4.0 in /databricks/python3/lib/python3.12/site-packages (from ipykernel!=7.0.0,!=7.0.1->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (5.14.3)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /databricks/python3/lib/python3.12/site-packages (from ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in /databricks/python3/lib/python3.12/site-packages (from ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in /databricks/python3/lib/python3.12/site-packages (from ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (1.0.0)
# Requirement already satisfied: mdurl~=0.1 in /databricks/python3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->cookiecutter->mesa==2.4.0) (0.1.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /databricks/python3/lib/python3.12/site-packages (from reacton>=1.9->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (4.12.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /databricks/python3/lib/python3.12/site-packages (from nbformat->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (2.21.1)
# Requirement already satisfied: jsonschema>=2.6 in /databricks/python3/lib/python3.12/site-packages (from nbformat->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (4.23.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /databricks/python3/lib/python3.12/site-packages (from starlette->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (4.6.2)
# Requirement already satisfied: h11>=0.8 in /databricks/python3/lib/python3.12/site-packages (from uvicorn->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (0.14.0)
# Requirement already satisfied: sniffio>=1.1 in /databricks/python3/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (1.3.0)
# Requirement already satisfied: decorator in /databricks/python3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /databricks/python3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /databricks/python3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (4.8.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /databricks/python3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (3.0.43)
# Requirement already satisfied: stack_data in /databricks/python3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (0.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /databricks/python3/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /databricks/python3/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /databricks/python3/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /databricks/python3/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (0.22.3)
# Requirement already satisfied: platformdirs>=2.5 in /databricks/python3/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel!=7.0.0,!=7.0.1->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (3.10.0)
# Requirement already satisfied: notebook>=4.4.1 in /databricks/python3/lib/python3.12/site-packages (from widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (7.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /databricks/python3/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (0.8.4)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /databricks/python3/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /databricks/python3/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (2.27.3)
# Requirement already satisfied: jupyterlab<4.4,>=4.3.4 in /databricks/python3/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (4.3.4)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /databricks/python3/lib/python3.12/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (0.2.3)
# Requirement already satisfied: ptyprocess>=0.5 in /databricks/python3/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (0.7.0)
# Requirement already satisfied: wcwidth in /databricks/python3/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (0.2.5)
# Requirement already satisfied: executing in /databricks/python3/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (0.8.3)
# Requirement already satisfied: asttokens in /databricks/python3/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (2.0.5)
# Requirement already satisfied: pure-eval in /databricks/python3/lib/python3.12/site-packages (from stack_data->ipython>=7.23.1->ipykernel!=7.0.0,!=7.0.1->solara-server==1.52.0->solara-server[dev,starlette]==1.52.0->solara->mesa==2.4.0) (0.2.2)
# Requirement already satisfied: argon2-cffi>=21.1 in /databricks/python3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /databricks/python3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /databricks/python3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /databricks/python3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (7.16.4)
# Requirement already satisfied: overrides>=5.0 in /databricks/python3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in /databricks/python3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (0.21.0)
# Requirement already satisfied: send2trash>=1.8.2 in /databricks/python3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /databricks/python3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in /databricks/python3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /databricks/python3/lib/python3.12/site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /databricks/python3/lib/python3.12/site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (0.27.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /databricks/python3/lib/python3.12/site-packages (from jupyterlab<4.4,>=4.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (2.2.0)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab<4.4,>=4.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (74.0.0)
# Requirement already satisfied: babel>=2.10 in /databricks/python3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /databricks/python3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (0.9.25)
# Requirement already satisfied: argon2-cffi-bindings in /databricks/python3/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (21.2.0)
# Requirement already satisfied: httpcore==1.* in /databricks/python3/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab<4.4,>=4.3.4->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (1.0.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in /databricks/python3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (3.2.1)
# Requirement already satisfied: rfc3339-validator in /databricks/python3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /databricks/python3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /databricks/python3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /databricks/python3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (6.2.0)
# Requirement already satisfied: defusedxml in /databricks/python3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /databricks/python3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /databricks/python3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in /databricks/python3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /databricks/python3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (1.5.0)
# Requirement already satisfied: tinycss2 in /databricks/python3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (1.4.0)
# Requirement already satisfied: webencodings in /databricks/python3/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (0.5.1)
# Requirement already satisfied: fqdn in /databricks/python3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (1.5.1)
# Requirement already satisfied: isoduration in /databricks/python3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /databricks/python3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (3.0.0)
# Requirement already satisfied: uri-template in /databricks/python3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /databricks/python3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /databricks/python3/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /databricks/python3/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (2.5)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets>=7.7->solara-ui==1.52.0->solara-ui[all]==1.52.0->solara->mesa==2.4.0) (2.21)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
import mesa
#from mesa.visualization import SolaraViz, Slider
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
from matplotlib.colors import ListedColormap
import numpy as np
import time
import mesa
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import numpy as np
from IPython.display import display, clear_output
import ipywidgets as widgets
import asyncio
import threading  
import nest_asyncio
import warnings
from matplotlib.patches import Patch

warnings.filterwarnings('ignore')
nest_asyncio.apply()

# %%
# Keep your Forest and ForestFire classes
class Forest(mesa.Agent):
    def __init__(self, unique_id, model, position):
        super().__init__(unique_id, model)
        self.pos = position
        self.status = "Fine"
    def step(self):
        if self.status == "Burning":
            for neighbor in self.model.grid.iter_neighbors(self.pos, True):
                if neighbor.status == "Fine":
                    if self.model.random.random() > 0.25:
                        neighbor.status = "Burning"
                self.status = "Burned"


class ForestFire(mesa.Model):
    def __init__(
        self,
        width=100,
        height=100,
        density=0.65,
        regeneration_time=10,
        regeneration_rate=0.1
    ):
        super().__init__()
        self.width = width
        self.height = height
        self.density = density
        self.schedule = mesa.time.RandomActivation(self)
        self.regeneration_time = regeneration_time
        self.regeneration_rate = regeneration_rate
        
        self.grid = mesa.space.SingleGrid(self.width, self.height, torus=False)
        
        self.datacollector = mesa.DataCollector(
            model_reporters={
                "Fine": lambda model: self.count_type(model, "Fine"),
                "Burning": lambda model: self.count_type(model, "Burning"),
                "Burned": lambda model: self.count_type(model, "Burned"),
            }
        )
        
        self._initialize_forest()
        self.datacollector.collect(self)
        
    def _initialize_forest(self):
        for x in range(self.width):
            for y in range(self.height):
                pos = (x, y)
                forest = Forest(self.next_id(), self, pos)
                if self.random.random() < self.density:
                    if x == 0:
                        forest.status = "Burning"
                    else:
                        forest.status = "Fine"
                else:
                    forest.status = "Burned"
                self.grid.place_agent(forest, pos)
                self.schedule.add(forest)
            
            
    def step(self):
        self.schedule.step()
        self.datacollector.collect(self)
        
    @staticmethod
    def count_type(model, status):
        count = 0
        for forest in model.schedule.agents:
            if forest.status == status:
                count += 1
        return count

# %%
class InteractiveForestFire:
    def __init__(self):
        self.model = None
        self.running = False
        self.step_count = 0

        # Runners & guards
        self._task = None              # asyncio.Task (if using asyncio)
        self._thread = None            # threading.Thread (fallback)
        self._stop_event = threading.Event()
        self._rendering = False        # prevent overlapping redraws

        # Create widgets
        self.play_button  = widgets.Button(description="▶️ Play",  button_style='success')
        self.step_button  = widgets.Button(description="⏭️ Step")
        self.reset_button = widgets.Button(description="🔄 Reset", button_style='danger')
        self.stop_button  = widgets.Button(description="⏹️ Stop",  button_style='info')

        self.width_slider  = widgets.IntSlider(value=100, min=20, max=150, step=10, description='Width:')
        self.height_slider = widgets.IntSlider(value=100, min=20, max=150, step=10, description='Height:')
        self.density_slider = widgets.FloatSlider(value=0.65, min=0.1, max=1.0, step=0.05, description='Density:')
        # self.regen_time_slider = widgets.IntSlider(value=10, min=1, max=50, step=1, description='Regen Time:')
        # self.regen_rate_slider = widgets.FloatSlider(value=0.1, min=0.01, max=0.5, step=0.01, description='Regen Rate:')

        self.output = widgets.Output()

        # Connect buttons
        self.play_button.on_click(self.toggle_play)
        self.step_button.on_click(self.do_step)
        self.reset_button.on_click(self.reset_simulation)
        self.stop_button.on_click(self.stop_simulation)

        # Initialize model
        self.reset_simulation()

    # ---------- UI helpers ----------
    def _set_play_ui(self, playing: bool):
        if playing:
            self.play_button.description = "⏸️ Pause"
            self.play_button.button_style = 'warning'
        else:
            self.play_button.description = "▶️ Play"
            self.play_button.button_style = 'success'

    # ---------- Start/Stop/reset ----------
    def toggle_play(self, button):
        self.running = not self.running
        if self.running:
            self._set_play_ui(True)
            self.run_simulation()
        else:
            self.stop_simulation()

    def stop_simulation(self, button=None):
        # Stop flag
        self.running = False
        self._stop_event.set()

        # Cancel asyncio task if any
        if self._task is not None:
            t = self._task
            self._task = None
            if not t.done():
                t.cancel()

        # Join thread if any
        if self._thread is not None and self._thread.is_alive():
            self._thread.join(timeout=1.0)
        self._thread = None

        self._set_play_ui(False)
        # Optional clean redraw
        self.update_display()

    def reset_simulation(self, button=None):
        # Fully stop any runner
        self.stop_simulation()

        # Reset state
        self.step_count = 0

        # Rebuild model
        self.model = ForestFire(
            width=self.width_slider.value,
            height=self.height_slider.value,
            density=self.density_slider.value,
            # regeneration_time=self.regen_time_slider.value,
            # regeneration_rate=self.regen_rate_slider.value
        )
        self.update_display()

    # ---------- Runner selection ----------
    def run_simulation(self):
        if not self.running:
            return

        # If something is already running, don’t start another
        if (self._task is not None and not self._task.done()) or \
           (self._thread is not None and self._thread.is_alive()):
            return

        # Clear stop signal for new run
        self._stop_event.clear()

        # Prefer asyncio in environments where a loop is running
        try:
            loop = asyncio.get_running_loop()
            # If we got here without raising, schedule the async loop
            self._task = loop.create_task(self._async_loop())
        except RuntimeError:
            # No running loop (classic notebook/Colab older setups) -> use thread
            self._thread = threading.Thread(target=self._thread_loop, daemon=True)
            self._thread.start()

    async def _async_loop(self):
        try:
            while self.running:
                self.do_step()
                await asyncio.sleep(0.1)  # yield to UI
        except asyncio.CancelledError:
            pass

    def _thread_loop(self):
        while self.running and not self._stop_event.is_set():
            self.do_step()
            time.sleep(0.1)

    # ---------- One step + render ----------
    def do_step(self, button=None):
        if not self.model:
            return
        if self._rendering:
            return  # skip if a draw is underway
        self._rendering = True
        try:
            self.model.step()
            self.step_count += 1
            self.update_display()
        finally:
            self._rendering = False

    # ---------- Drawing ----------
    def update_display(self):
        if self.model is None:
            return

        with self.output:
            clear_output(wait=True)

            fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

            # Grid visualization
            W, H = self.model.grid.width, self.model.grid.height
            grid = np.zeros((W, H))
            status_to_num = {"Burned": 0, "Fine": 1, "Burning": 2}

            for agent in self.model.agents:
                if hasattr(agent, 'pos') and hasattr(agent, 'status'):
                    x, y = agent.pos
                    if 0 <= x < W and 0 <= y < H:
                        grid[x][y] = status_to_num.get(agent.status, 0)

            cmap = ListedColormap(["#3D2B1F", "#00AA00", "#FF0000"])
            ax1.imshow(grid.T, cmap=cmap, origin="lower", vmin=0, vmax=2)
            ax1.set_title(f"Forest Grid - Step {self.step_count}", fontsize=14, fontweight='bold')
            ax1.set_xlabel("X")
            ax1.set_ylabel("Y")
            ax1.set_xticks([])
            ax1.set_yticks([])
            legend_elements = [
                Patch(facecolor='#3D2B1F', label='Burned'),
                Patch(facecolor='#00AA00', label='Fine'),
                Patch(facecolor='#FF0000', label='Burning')
            ]
            ax1.legend(handles=legend_elements, loc='upper right')

            # Chart visualization
            df = self.model.datacollector.get_model_vars_dataframe()
            if df is not None and not df.empty:
                ax2.plot(df.index, df["Fine"],    label="Fine Trees", linewidth=2)
                ax2.plot(df.index, df["Burning"], label="Burning",    linewidth=2)
                ax2.plot(df.index, df["Burned"],  label="Burned",     linewidth=2)

                ax2.set_xlabel("Step", fontsize=12)
                ax2.set_ylabel("Count", fontsize=12)
                ax2.set_title("Forest Status Over Time", fontsize=14, fontweight='bold')
                ax2.legend(fontsize=10)
                ax2.grid(True, alpha=0.3)
                ax2.set_ylim(0, W * H)

            plt.tight_layout()
            plt.show()

    # ---------- UI layout ----------
    def display(self):
        controls = widgets.HBox([self.play_button, self.step_button, self.reset_button, self.stop_button])
        sliders = widgets.VBox([
            self.width_slider,
            self.height_slider,
            self.density_slider,
            # self.regen_time_slider,
            # self.regen_rate_slider
        ])

        ui = widgets.VBox([
            widgets.HTML("<h1>🔥 Forest Fire Simulation with Regeneration</h1>"),
            controls,
            sliders,
            self.output
        ])

        display(ui)

# Run the simulation
sim = InteractiveForestFire()
sim.display()
# Out:
# VBox(children=(HTML(value='<h1>🔥 Forest Fire Simulation with Regeneration</h1>'), HBox(children=(Button(button…
